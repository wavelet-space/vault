# %% [markdown]
# # R Homework 01
#
# - David Landa
#
# 1. Display the whole vector. What is the area of Luzon?
# 2. What is the average value of the whole vector?
# 3. Which continent is the largest and what is its area?
# 4. Which continents/islands have an area larger than 5000?
# 5. Display the names of 15 smallest and largest continents/islands.
# 6. Assuming that these are British miles, recalculate the data to km2 (1 sq mi = 2.59 km2)

# %%
data(islands)
# [1]
islands
# Out:
#           Africa       Antarctica             Asia        Australia
#            11506             5500            16988             2968
#     Axel Heiberg           Baffin            Banks           Borneo
#               16              184               23              280
#          Britain          Celebes            Celon             Cuba
#               84               73               25               43
#            Devon        Ellesmere           Europe        Greenland
#               21               82             3745              840
#           Hainan       Hispaniola         Hokkaido           Honshu
#               13               30               30               89
#          Iceland          Ireland             Java           Kyushu
#               40               33               49               14
#            Luzon       Madagascar         Melville         Mindanao
#               42              227               16               36
# ...

# %%
# [2]
mean(islands)
# Out:
# [1] 1252.729

# %%
# [3]
islands[which.max(islands)]
# Out:
#  Asia
# 16988

# %%
# [4]
islands[which(islands > 5000)]
# Out:
#        Africa    Antarctica          Asia North America South America
#         11506          5500         16988          9390          6795

# %%
# [5]
# 15 smallest
head((sort(islands)), 15)
# Out:
#        Vancouver           Hainan  Prince of Wales            Timor
#               12               13               13               13
#           Kyushu           Taiwan      New Britain      Spitsbergen
#               14               14               15               15
#     Axel Heiberg         Melville      Southampton Tierra del Fuego
#               16               16               16               19
#            Devon            Banks            Celon
#               21               23               25

# %%
# 15 largest
tail(sort(islands), 15)
# Out:
#       Britain        Honshu       Sumatra        Baffin    Madagascar
#            84            89           183           184           227
#        Borneo    New Guinea     Greenland     Australia        Europe
#           280           306           840          2968          3745
#    Antarctica South America North America        Africa          Asia
#          5500          6795          9390         11506         16988

# %%
# or
head(sort(islands, decreasing = TRUE), 15)
# Out:
#          Asia        Africa North America South America    Antarctica
#         16988         11506          9390          6795          5500
#        Europe     Australia     Greenland    New Guinea        Borneo
#          3745          2968           840           306           280
#    Madagascar        Baffin       Sumatra        Honshu       Britain
#           227           184           183            89            84

# %%
length(head(sort(islands, decreasing = TRUE), 15)) # test number of items
# Out:
# [1] 15

# %%
# [6]
islands * 2.59
# Out:
#           Africa       Antarctica             Asia        Australia
#         29800.54         14245.00         43998.92          7687.12
#     Axel Heiberg           Baffin            Banks           Borneo
#            41.44           476.56            59.57           725.20
#          Britain          Celebes            Celon             Cuba
#           217.56           189.07            64.75           111.37
#            Devon        Ellesmere           Europe        Greenland
#            54.39           212.38          9699.55          2175.60
#           Hainan       Hispaniola         Hokkaido           Honshu
#            33.67            77.70            77.70           230.51
#          Iceland          Ireland             Java           Kyushu
#           103.60            85.47           126.91            36.26
#            Luzon       Madagascar         Melville         Mindanao
#           108.78           587.93            41.44            93.24
# ...
