# %% [markdown]
# # Petrology
#
# ## Magmatic rocks
#
# ## Metamorphic rocks
#
# ## Sedimantary rocks

# %% [markdown]
# # Horninové minerály
#
# ## Amfibol (group)
#
# __Amfibol__ (/ˈæmfɪboʊl/) je skupina inosilikátů.
#
# ## Pyroxen (group)
#
# https://www.mindat.org/min-9767.html
#
# ### Clinopyroxen subgroup (monoclinic)
# ### Orthopyroxen subgroup (orthorhombic)

# %% [markdown]
# # Petrologie
#
# ## Seznam hornin
#
# Seznam hornin pro idetifikaci hornin extrahovaný z původních PDF dokumentů, který vytvořil prof. David Dolejš [http://www.minpetro.uni-freiburg.de/team/dolejs](http://www.minpetro.uni-freiburg.de/team/dolejs).
#
# > Tento seznam obsahuje pouze charakteristické poznávací znaky hornin. Jednotlivé vzorky mohou mít určité přirozené
# odchylky, zvláštnosti apod., ale zase není dobré příliš pečlivým studiem získat dojem, že horniny jsou bezmezně
# proměnlivé a mezi sebou vzájemně nerozpoznatelné. -- David Dolejš
#
# Dále je dostupný v adresáři na githubu další PDF dokument od stejného autora s názvem *Návod k poznávání hornin. David Dolejš.pdf*.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
#rocks = pd.read_csv("rocks.psv", delimiter="|")

# %% [markdown]
# ### Minerals
#
# Minerals and their symbols:
#
# ## Magmatické horniny

# %%
"""
Ab		Albit
Act		Aktinolit
Aeg		Egerin
Alm		Almandin
Als		Alumosilikát
Am		Amfibol
An		Anortit
And		Andalusit
Bt		Biotit
Car		Karfolit
Cc		Kalcit
Chl		Chlorit
Cpx		Klinopyroxen
Crd		Kordierit
Ctd		Chloritoid
Di		Diopsid
Ed		Edenit
En		Enstatit
Ep		Epidot
Fa		Fayalit
Fs		Ferosilit
Fo		Forsterit
Gl		Glaukofán
Grs		Grossular
Hbl		Hornblend
Hd		Hedenbergit
Jd		Jadeit
Kfs		K-Živec
Kln		Kaolinit
Ky		Kyanit
Lws		Lawsonit
Ms		Muskovit
Pl		Plagioklas
Prh		Prehnit
Prl		Pyrofylit
Pmp		Pumpellyit
Prg		Pargasit
Px		Pyroxene
Qtz		Křemen
Ol		Olivin
Omph	Omfacit
Opx		Ortopyroxen
Ph		Fengit
Ric		Richterit
Rb		Riebeckit
Sill	Sillimanit
Sp		Spinel
St		Staurolite
Tar		Taramit
Tc		Mastek (talc)
Tnt		Titanit
Tr		Tremolit
Ts		Tscermakit
Wo		Wolastonit
Zeo		Zeolit
Zo		Zoisit
"""
# Out:
# '\nAb\t\tAlbit\nAct\t\tAktinolit\nAeg\t\tEgerin\nAlm\t\tAlmandin\nAls\t\tAlumosilikát\nAm\t\tAmfibol\nAn\t\tAnortit\nAnd\t\tAndalusit\nBt\t\tBiotit\nCar\t\tKarfolit\nCc\t\tKalcit\nChl\t\tChlorit\nCpx\t\tKlinopyroxen\nCrd\t\tKordierit\nCtd\t\tChloritoid\nDi\t\tDiopsid\nEd\t\tEdenit\nEn\t\tEnstatit\nEp\t\tEpidot\nFa\t\tFayalit\nFs\t\tFerosilit\nFo\t\tForsterit\nGl\t\tGlaukofán\nGrs\t\tGrossular\nHbl\t\tHornblend\nHd\t\tHedenbergit\nJd\t\tJadeit\nKfs\t\tK-Živec\nKln\t\tKaolinit\nKy\t\tKyanit\nLws\t\tLawsonit\nMs\t\tMuskovit\nPl\t\tPlagioklas\nPrh\t\tPrehnit\nPrl\t\tPyrofylit\nPmp\t\tPumpellyit\nPrg\t\tPargasit\nPx\t\tPyroxene\nQtz\t\tKřemen\nOl\t\tOlivin\nOmph\tOmfacit\nOpx\t\tOrtopyroxen\nPh\t\tFengit\nRic\t\tRichterit\nRb\t\tRiebeckit\nSill\tSillimanit\nSp\t\tSpinel\nSt\t\tStaurolite\nTar\t\tTaramit\nTc\t\tMastek (talc)\nTnt\t\tTitanit\nTr\t\tTremolit\nTs\t\tTscermakit\nWo\t\tWolastonit\nZeo\t\tZeolit\nZo\t\tZoisit\n'

# %% [markdown]
# ## Sedimentární horniny

# %% [markdown]
# ## Metamorfované horniny

# %% [markdown]
# ## Otázky a odpovědi
#
# - Minerál, který má nejnižší obsah $SiO_2$ je: enstatit, forsferit bronzit, fayalit, hypersten, ferosilit.
#
# - Minerál, který má nejvyšší obsah $SiO_2$ je: enstatit, forsferit bronzit, fayalit, hypersten, ferosilit.
#
# - Olivín v horninách běžně podléhá: serpentinizaci, pinitizaci, albitizaci, karbonizaci, chloritizaci.
#
# - Biotiti v horninách běžně podléhá: serpentinizaci, pinitizaci, albitizaci, karbonizaci, chloritizaci.
#
# - Mezi fylosilikáty patří:
#   - serpentin, mastek, chlorit
#   - sericit, antofylit, serpentin
#   - kaolinit, muskovit, nefelín
#   - muskovit, biotit, kyanit
#
# - Vysoký obsah $CaCo$, tj. $Ca$ je přítomen nad 10 hm.%, mají minerály:
#   - biotit, wollastonit, anortit, mastek
#   - paragonit, muskovit, cordierit, kaolinit
#   - augit, jadeit, pyrop, diopsid
#   - grossular, epodit, apatit, dolomit
#
# - Minerál, který má nejvyšší obsah $Al_2O$ je: anortit, albit, andezín, sanidin, ortoklas.
#
#
# ## Zdroje
#
# http://departments.fsv.cvut.cz/k135/wwwold/webkurzy/petro/
# https://is.muni.cz/do/1499/el/estud/pedf/ps06/2722682/petro/soubory/skripta.htm
# http://petrol.sci.muni.cz/poznavanihornin/horniny.htm
#
# # Magmatické
#
# ## Hlubinné
#
# ##
#
# ##
#
# # Sedimentární horniny
#
# ## Siliciklastika
#
# #### Zrnitost
#
# - Psefit
# - Psamit
# - Aulerit
# - Pelit
# - AuleroPelit
# - Rudit
# - Arenit
# - Lulit
#
# #### Vytřídení
#
# #### Sféricita
#
# tvary a povrch zrn
# prostorové uspořádání zr
#
#
# ## Pelitické horniny (Pelity)
#
# Sedimenty s velikostí klastů pod 0.0004mm (tzv. fyzikální jíl) nebo s převahou
#
# ## Karbonáty
#
# ##
#
# # Metamorfované horniny
#
# ### 1. Ultra Mafické horniny
#
# *svrchní plášť*
#
# - Peridotit
#
# - Serpentinit
#
# ### 2. Mafické horniny
#
# *oceánská kůra, kontinetální rift, platóbasalt*
#
# ### 3. Kyselé a intermediální magmatity
#
# - MetaGranit
# - MetaGranoDioritá
# - MetaTonalit
#
# *nízký stupeň*
#
# chloritizace biotit, amfibol
# sericitizace živec -> prehnit, pumpellyit
#
# *střední stupeň*
#
# rekrystalizace živec
# tvorba biotit, muskovit, epidot
#
# - Ortorula
#
# - MetaRyolit
#
# *nízký stupěň*
#
# zrna živec, křemen v rekrytalizované zákl. hmotě
# tvorba chlorit, albit, muskovit, pumpellyit, epidot
#
# ### 4. Pelitické horniny
#
# Barrovianské metamorfní zóny -- izográda
#
# - Břidlice
#
# - Fylit (Phyllite)
#
# jílové mierály
#
# - Svor (Micaschit)
#
# - Pararula (Gneiss)
#
# - Migmatit
#
# z části rulová
#
# - Granulit
#
# Vysokotlaká metamorfóza -- přeměna minerálů:
# ...
#
# - MetaPsamit (MetaPískovec, MetaDroba)
#
# - MetaKonglomerát
# deformace valounů, rekrystalizace matrix
#
#
# ### 5. Karbonatická hornina
#
# - Mramor
#
# #### Bílá břidlice (WhiteSchist)
#
# ### 6. Ca-Si hornina: Skarn, Erlán
#
# výsledek metasomatózy (zatlačování, substituce, nahrazování, alterace)
#
# - Skarn
#  - Wolass
# - Erlán
#
# #### 8. Kvarcit (Quartzite)
#
# ### Facie Kontaktní metamorfózy
#
# - Epidotický Rohovec
#
#
#
# # Otázky
#
# Metamorfované a Magmatické
#
# vzorce živců
#
# co je to dunit
# co je to bazanit
#
# minerální asociace svoru
#
# Sedimenty
#
# nakreslete mazdrité a čočkovité zvrstvení a popsat
# trojúhelníkový diagram sedimentu a určit ho a popsat vznik
#
#
# ### Dělení Pyroxenů
#
# ortopyroxeny – kosočtverečné pyroxeny
# klinopyroxeny – jednoklonné pyroxeny
# Mezinárodní mineralogická asociace (IMA) dělí pyroxeny podle složení do šesti skupin:
#
# Mg-Fe pyroxeny
# Mn-Mg pyroxeny
# Ca pyroxeny
# Ca-Na pyroxeny
# Na pyroxeny
# Li pyroxeny
# V těchto šesti skupinách je stanoveno 20 základních druhů:
#
# Mg-Fe pyroxeny
#
# Mg-Fe pyroxeny krystalují v kosočtverečné nebo monoklinické soustavě.
#
# enstatit (kosočtverečná) Mg2Si2O6
# ferrosillit (kosočtverečná) Fe2+2Si2O6
# klinoenstatit (monoklinická) Mg2Si2O6
# klinoferrosillit (monoklinická) Fe2+2Si2AlO6
# pigeonit (monoklinická) (Mg,Fe2+,Ca)2Si2AlO6
# Mn-Mg pyroxeny
# Krystalují v kosočtverečné či monoklinické soustavě.
#
# donpeacorit (kosočtverečná): (Mn2+,Mg)MgSi2O6
# kanoit (monoklinická): Mn2+MgSi2O6
# Ca pyroxeny
# všechny krystalují v monoklinické soustavě.
#
# diopsid: CaMgSi2O6
# hedenbergit: CaFe2+Si2O6
# augit: (Ca,Mg,Fe2+)2Si2O6
# johannsenit: CaMnSi2O6
# petedunnit: CaZnSi2O6
# esseneit: CaFe3+AlSiO6
# Ca-Na pyroxeny
#
# Ca-Na pyroxeny
# omfacit: (Ca,Na)(R2+Al)Si2O6
# egirín-augit: (Ca,Na)(R2+Fe3+)Si2O6
# Na pyroxeny
# jadeit: NaAlSi2O6
# egirín: NaFe3+Si2O6
# kosmochlor: NaCr3+Si2O6
# jervisit: NaSc3+Si2O6
# namansilit: NaMn3+Si2O6
# natalyit: NaV3+Si2O6
# Li pyroxeny
# spodumen: LiAlSi2O6
