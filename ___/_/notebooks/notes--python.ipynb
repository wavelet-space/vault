# %% [markdown]
# # Programování v jazyce Python
#
# Proč používat Python, jaké má výhody nevýhody oproti jiným prostředím a jazykům?
#
# ## Vytvoření a správa projektu.
#
# Správa projektu pomocí nástroje Git.
# Správa projektu pomocí nástroje Poetry.
#
# ## Vytvoření Jupyter Notebook.
#
# ## Základy jazyka Python
#
# Co je to package a module?
# Co je to proměnná, funkce, třída?
# Mám vytvářet třídu nebo funkce?
# Co je to dědičnost a kdy ji využít?
# Co je to Liskovové substitučí princip?
# Co je to dynamické typování, jaké má předosti a úskalí?
# Čtení a zápis dat.
#
# ## Vědecké výpočty
#
# (Scipy, Numpy, Pandas)
#
# Kdy použít numpy a opravdu urychlí můj program?
#
# Práce s tabulkovými daty pomocí Pandas.
# Jak na konzolovou aplikaci.
# Co je to rozhraní modulu aneb na co je `__all__`.
#
# ### Numerické výpočty
#
# vektor, matice, tenzor, skalární součin, vektorový součin
# derivace, integrace, interpolace
#
# ### Symbolické výpočty
#
# derivace, integrace
#
# ### Statistické výpočty
#
# statistické distribuce, náhodná čísla, vytváření grafů (matplotlib, seaborn, bokeh atd.)
# histogram, bar chart, stacked bar chart, rose chart
#
# ## Přehled modulů standardní knihovny
#
# ## Testování pomocí balíku pytest.
#
# K čemu je soubor setup.py.
#
# dash, pandas, matplotlib, seaborn.
#
#
#
# # Python Course
#
# ## Overview
#
# ### Stage 1
#
# In the *Stage 1* you will not only learn the basics of Python programming language, but also how to setup your development environment, how to use the command line interface and how to use another services as `Github` together with *Git* tool. Your knowledge after this stage will be shallow but you will be able to solve some basic and practical problems.
#
# 1.1
#   1.1.2 Installation and usage of command line interface (ConEmu,Terminal)
#   1.1.1 Installation of Python (v3) interpeter
#   1.1.3 Overview of Github service and creation of an account
#   1.1.4 Installation of Git and basic commands
# 1.2
#   1.2.1 Your first Python program
#   2
#
# ### Stage 2
#
# In the *Stage 2*
#
# ### Level 3
#
# ## Datatypes
#
# 	Number
# 	List
# 	Tuple
# 	String
# 	Set
# 	Dictionary
# 	Array
# 	Matrix
#
# ## Functions
#
# 	builtin
# 	custom
#
# ## Comprehension (list)
#
# ## Classes
# 	Inheritance & Abstract classes
# 		Single vs Multi
#
# 	Operators
#
# ## Properties
#
# ## Closures
# https://www.programiz.com/python-programming/closure
#
# ## Iterators
#
# ## Generators
#
# ## Decorators
#
# ## Reflection

# %%
import  matplotlib.pyplot as plt
from sympy.physics.vector import ReferenceFrame
from sympy.physics.vector import curl


R = ReferenceFrame('R')
F = R[0] * R[1] * R[2] * R.x
curl(F, R)
# Out:
# R_x*R_y*R.y - R_x*R_z*R.z
