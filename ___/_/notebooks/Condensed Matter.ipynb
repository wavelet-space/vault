# %% [markdown]
# # <span style="font-size: 6em">Solids</span>
#
# - Mathematics
# - Geodynamics
# - Programming
#
# # Crystall Lattice

# %% [markdown]
# ## Kubická (*cubic*)
#
# ## Ortorombická (*orthorombic*)
#
# ## Monoklinická (*monoclinic*)
#
# ## Triclinic (*triclinic)*

# %% [markdown]
# # Poruchy krytalové mříže
#
# > Krystal s dokonalou krystalovou mříží se nazývá dokonalý krystal.
#
# ### Krystal s ideální krystalovou mříží se nazývá ideální krystal. Jeho atomy jsou v místech s minimální potenciální energiií.
#
# ### Každá nepravidelnost (porucha) krystalové mříže způsobuje deformaci vlivem pnutí krystalové mříže.
#
# ### Z hlediska topologie můžeme poruchy rozlišit na bodové, čárové, ploč
#
# ### Bodová porucha
#
# ### Čárová porucha
#
# ### Plošná porucha
#
# ### Objemová porucha
#
#
# https://www.rigb.org/our-history/bragg-film-archive/bubble-rafts/bubble-model-of-a-metal

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("https://www.youtube.com/watch?list=PLal2Dq06taLYKmIyoqleynvWms7ndaHyY&v=DhYXBDBd7-Q")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?list=PLal2Dq06taLYKmIyoqleynvWms7ndaHyY&v=DhYXBDBd7-Q"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Dislokační šplhání (*dislocation climbing*)
#
#
#
# ## Dislokační *recovery*
#
# ## Dislokační skluz

# %% [markdown]
# # Pevnost krystalu ve smyku
#
# ## Frenklova analýza pevnosti dokonalého krystalu (periodický model)
#
# Frenkel (J. Frenkel, Zeitschrift fur Physik 37 (1926) p. 572) odvodil teoretickou pevnost ve smyku z napětí, které je potřebné k posunutí dvou atomové vrstvev materiálu vůči sobě.
#
# ![obrazek.png](attachment:b6cd1f55-1ed3-4d4e-a234-b43d91310d72.png)
#
# __Předpoklad__ Mějme dvě roviny o mezirovinné vzdálenost (interplanar spacing) $a$ s meziatomovou vzdáleností (interatomic spacing) $b$, které se při posunu nedeformují. Smyskové napětí $\tau$ potřebné k pohyby vrstev vůži sobě má v přiblížení sinusový průběh.
#
# $$
#     \tau = \tau_{max} \sin \frac{2 \pi x}{b} \approx
# $$
#
# - Slip plane
# - Slip direction
# - Critical shear stress
# - Atom displacement
#
# ## Kohesivní síla mezi dvěma atomy
#
# ...

# %% [markdown]
# __EXAMPLE__
#
# ___Determine the theoreical load, which can be supported by a copper wire of 1 mm in diameter.___
#
# $$
# \tau_{theor} = \frac{d}{a} \frac{G}{2\pi}
# $$
#
# Měď má kubickou plošně centrovanou mřížku (FCC) s mřížkovým parametrem $a = 3.59 10^{-10}m$. V systém FCC mají skluzové roviny Millerův symbol ${111}$. Mezirovinná vzdálenost $d_{111} = \frac{a}{\sqrt{h^2 + k^2 + l^2}} = \frac{a}{\sqrt{3}}$. Počítáme s $\mu = 44.7 GPa$. Dosazením do $F = \tau \cdot A$ dostaneme, že maximální teoretická síla, kterou můžeme drát zatížit je $328,4 kg$

# %%
from math import pi, sqrt

a = 3.59e-10                   # [meter] lattice parameter
d = 3.59e-10 / sqrt(3)         # [meter] interplane distance
G = 44.7e9                     # [Pa]

Area = (pi * (0.0005 ** 2))    # [m^2]
τ = (d / a) * (G / (2.0 * pi))
F = τ * Area
g = 9.823                      # m·s^{-2}
m = F / g

print(m)
# Out:
# 328.40727161733014

# %% [markdown]
# ![obrazek.png](attachment:eaab542c-917b-4f7c-ac7f-306cdc5abd93.png)
#
# Figure 2. Sketch illustrating that (a) the movement of an edge dislocation, e, and (b) the movement of a screw dislocation, s, with the same Burgers vector (c) produce the same displacement of the upper half of a crystal relative to the lower half. Adapted from Kelly A and Groves GW (1970) Crystallography and Crystal Defects, 428 pp. Reading, MA: Addison-Wesley Publishing Company.

# %% [markdown]
# > Burger's Circuit
#
# > Burger's Vector
#
# > Slip Band
#
# > Dislocation Line
#
# > Dislocation Loop
#
# > Screw Dislocation
#
# > Schmid's law (also Schmid factor) describes the slip plane and the slip direction of a stressed material,
# which can resolve the most shear stress.
#
# > Slip Direction
#
# > Slip Plane
#
# > Slip system describes the set of symmetrically identical slip planes and associated family of slip directions

# %% [markdown]
# # Stress
#
# # Strain
#
#
# # Rheology
#
# - Reologie se zabývá vlastnostmi materiálu zejména jeho plastického chování, pokud je vystaven napětí.
#
# ## Fluids
#
# - Viskozita je veličina vyjadřující míru odporu tekutiny k tečení.
#
# $$ \eta := [Pa.s] $$
#
# - Rychlostní profil Newtonovské tekutiny má tvar paraboly.
# - Rychlostní profil Binghamovské tekutiny je charakteritický čelní plošinou.
#
# ## Solids
#
# ## Resources
#
# - https://www.continuummechanics.org/
