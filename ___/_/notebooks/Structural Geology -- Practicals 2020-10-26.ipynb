# %%
import numpy as np
import sympy as sp

from visual import DisplacementFieldGraph, Ellipse, Square

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
A = np.array([
    [np.sqrt(2.0), -1.0/np.sqrt(8.0)], 
    [np.sqrt(2.0), 1.0/np.sqrt(8.0)]
])

# %%
A
# Out:
# array([[ 1.41421356, -0.35355339],
#        [ 1.41421356,  0.35355339]])

# %%
B = A @ A.T

# %%
eigen_values, eigen_vectors = np.linalg.eig(B)

# %%
eigen_values
# Out:
# array([4.  , 0.25])

# %%
eigen_vectors
# Out:
# array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]])

# %%
sp.Matrix(eigen_vectors)
# Out:
# Matrix([
# [0.707106781186548, -0.707106781186547],
# [0.707106781186547,  0.707106781186548]])

# %%
import  matplotlib.pyplot as plt

x,y = np.meshgrid(np.linspace(-10, 10, 30),np.linspace(-10, 10, 30))

u = x * np.sqrt(x**2 + y**2)
v = y * np.sqrt(x**2 + y**2)

plt.quiver(x, y, u, v, color="red")

# %%
DisplacementFieldGraph.from_deformation_gradient(A)

# %%
Square(A)

# %%
Ellipse.from_deformation(A)
